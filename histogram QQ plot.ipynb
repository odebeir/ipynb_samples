# %%
import numpy as np
import skimage.data as data
import skimage
from scipy.interpolate import interp1d

print skimage.__version__
# %pylab inline
# Out:
# 0.10dev
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['f']
# `%matplotlib` prevents importing * from pylab and numpy

# %%
def histos(ima):
    h,bin = np.histogram(ima[:],range(257))
    cumh = np.cumsum(h)
    norm_cumh = 1.*cumh/cumh[-1]
    f = interpolate.interp1d(norm_cumh, bin[:-1],bounds_error=False)       
    return h,norm_cumh,f

# %%
def plot_histos(h,ima=None):
    if ima is None:
        fig,ax = plt.subplots(figsize=(8,4))
        ax = [ax]
    else:
        fig,ax = plt.subplots(1,2,figsize=(8,4))
        
    ax[0].plot(h[0])
    ax[0].set_ylabel('histo')
    ax2 = ax[0].twinx()
    ax2.plot(h[1],'r')
    ax2.set_ylabel('cumul',color='r')
    for tl in ax2.get_yticklabels():
        tl.set_color('r')
    if ima is not None:
        ax[1].imshow(ima,vmin=0,vmax=255,cmap=cm.gray)
        ax[1].axis('off')

# %% [markdown]
# Build different version of the original image using linear and non linear modifications

# %%
g = data.camera()
modifier = []
modifier.append('.5*g')
modifier.append('.5*g + 64')
modifier.append('.25*g + 128')
modifier.append('.05*g + 128')
modifier.append('(255.*(1.*g)**2)/(255.**2)')
modifier.append('128./(1+np.exp(.005*(255.-g)))')

# %%
h = histos(g)
plot_histos(h,g)
ref = h[2]

for m in modifier:
    f = eval('lambda g:%s'%m)
    g_mod = f(g)
    h = histos(g_mod)
    plot_histos(h,g_mod)

# %% [markdown]
# Correction modified image to match original histogram

# %%
h = histos(g)
plot_histos(h,g)
ref = h[2]
plt.title('g')

for m in modifier:
    f = eval('lambda g:%s'%m)
    g_mod = f(g)
    h = histos(g_mod)
    #plot_histos(h,g_mod)
    
    lut = h[1]
    correct = ref(lut[g_mod.astype(np.uint8)])
    h = histos(correct)
    plot_histos(h,correct)
    plt.title(m)

# %% [markdown]
# Adjust the histogram of an image to match those of an other
#
# here Lena's histogram is adjusted to be similar the cameraman's histogram

# %%
lena = np.sum(data.lena(),axis=2)/3
h = histos(lena)
plot_histos(h,lena)
lut = h[1]
correct = ref(lut[lena])
h = histos(correct)
plot_histos(h,correct)

# %% [markdown]
# Image QQ plot

# %%
from numpy import sort
from numpy.random import permutation

N = 2000
sample_g = sort(permutation(g.flatten())[:N])
sample_g2 = sort(permutation(g4.flatten())[:N])
plt.plot(sample_g,sample_g2)
